# %%
2.0 * 3.0
# Out:
# 6.0

# %%
2 / 3
# Out:
# 0.6666666666666666

# %%
2 // 3.0
# Out:
# 0.0

# %%
2.0 + 3
# Out:
# 5.0

# %%
2 - 3.0
# Out:
# -1.0

# %%
2.0 ** 3
# Out:
# 8.0

# %%
import math
math.e ** abs(0.2-2)
# Out:
# 6.049647464412946

# %%
(10 ** 12) / (10 ** 9)
# Out:
# 1000.0

# %%
(10e+12) / (10e+9)
# Out:
# 1000.0

# %%
(1_0e+12) / (1_0e+9)
# Out:
# 1000.0
